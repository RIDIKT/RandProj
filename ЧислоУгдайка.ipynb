# %%
import random
import math


def serchminsres():
    number=x
    counter=0
    counter= math.log2(number + 1)
    counter=math. ceil(counter)
    print(counter)

    
def rnda():
    rndnum = random.randint(0, 100)
    return rndnum

    
def is_valid():
    if xs.isdigit():
        return True
    else:
        return False

        
def funs(xs,x):
    if int(xs) < 0 or int(xs)> 100:
        print("Число должно быть в диапозоне 1-100")
        #continue
    elif int(xs)<x:
        print("Число меньше загадного")
    elif int(xs)>x:
        print("Число больше загадного")
    else:
        print("Вы угадали число!!!")
        
        return xs
x = rnda()
#print(x)
print("Введите число:")

##################################################################################

xs=-1
while int(xs)!=x:
    xs=input()
    if is_valid():
        funs(xs,x)
    else:
        while is_valid()==False:
            print('Введите число а не текст или смволы:')
            xs=input()
print("Минимальное математическое колличество опреаций до угадывания числа = ",end="")
serchminsres()
# Out:
# Введите число:
#  42
# Число меньше загадного
#  55
# Число меньше загадного
#  66
# Число меньше загадного
#  77
# Число больше загадного
#  70
# Число меньше загадного
#  74
# Число больше загадного
#  73
# Число больше загадного
#  71
# Вы угадали число!!!
# Минимальное математическое колличество опреаций до угадывания числа = 7

# %%
##### x = rnda()
print(x)
print("Введите число:")

##################################################################################

xs=x+1
while int(xs)!= x:
    xs=input()
    if is_valid():
        funs(xs,x)
    else:
        while is_valid()==False:
            print('Введите число а не тест или смволы:')
            xs=input()
print("Минимальное математическое колличество опреаций до угадывания числа = ",end="")
serchminsres()
# Out:
# 42
# Введите число:
#  42
# Вы угадали число!!!
# Минимальное математическое колличество опреаций до угадывания числа = 6

# %%
while xs!= x:
    xs=int(input())
    func

    if func==
    break

# %%
xs=1
def is_valid():
    if type(xs)==int:
        return True
        print(1)
is_valid()
# Out:
# True
